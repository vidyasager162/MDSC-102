# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
names = ["Class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted Wine::::::::::::s","Proline"]
df = pd.read_csv('./Resources/wine/wine.data', names=names)

# %%
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
sns.boxplot(x="Alcohol", data=df)
# Out:
# <Axes: xlabel='Alcohol'>

# %%
sns.histplot(x="Alcohol", data=df, kde=True)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
sns.boxplot(x="Malic acid", data=df)
# Out:
# <Axes: xlabel='Malic acid'>

# %%
sns.histplot(x="Malic acid", data=df, kde=True)
# Out:
# <Axes: xlabel='Malic acid', ylabel='Count'>

# %%
sns.boxplot(x="Class", y="Alcohol", data=df)
# Out:
# <Axes: xlabel='Class', ylabel='Alcohol'>

# %%
plt.figure(figsize=(20,20))
for index, column in enumerate(df):
    if index > 0:
        plt.subplot(5,3,index)
        sns.boxplot(x="Class", y=column, data=df)

# %% [markdown]
# # Inference from the Box Plots
#
# ### Alcohol
# * Median Values across the classes differ and class 2 has some outliers.
#
# ### Malic acid
# * Class 1 and 2 share similar median values but they also have a lot of erraneous values or outliers.
#
# ### Ash
# * Class 1 and 3 share similar median values and class 2 comes around the same range.
#
# ### Alcalinity of ash
# * Class 3 looks like it is left-skewed and Class 1 and 2 have erraneous values or ourliers.
#
# ### Magnesium
# * Class 2 is left-skewed and has a lot of outliers.
#
# ### Total phenols
# * Class 1 and 3 have outliers and class 3 looks a little left-skewed.
#
# ### Flavanoids
# * Median Values vary across the classes and class 2 and 3 has outliers.
#
# ### Nonflavanoid phenols
# * Class 1 has outliers and the skewness looks normal.
#
# ### Proanthocyanins
# * Class 1 and 2 have closer median values and all classes have outliers.
#
# ### Color intensity
# * Class 1 and 2 have outliers.
#
# ### Hue
# * Median values of class 1 and 2 are closer with oultiers in class 2.
#
# ### OD280/OD315 of diluted Wine:s
# * Class 3 have outliers and all the different classes have varying median values.
#
# ### Proline
# * Class 2 is left skewed and has outliers.

# %%
plt.figure(figsize=(20,60))
i = 1
for column in df:
    if column == 'Class':
        continue
    plt.subplot(14,3,i)
    sns.histplot(df[df['Class'] == 1][column], kde=True)
    i += 1

    plt.subplot(14,3,i)
    sns.histplot(df[df['Class'] == 2][column], kde=True)
    i += 1

    plt.subplot(14,3,i)
    sns.histplot(df[df['Class'] == 3][column], kde=True)
    i += 1

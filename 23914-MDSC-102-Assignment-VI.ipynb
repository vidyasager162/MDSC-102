# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
names = ["Class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted Wines","Proline"]
df = pd.read_csv('./Resources/wine/wine.data', names=names)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
mag_mean = df['Magnesium'].mean()
dil_mean = df['OD280/OD315 of diluted Wines'].mean()
hue_mean = df['Hue'].mean()

mag_median = df['Magnesium'].median()
dil_median = df['OD280/OD315 of diluted Wines'].median()
hue_median = df['Hue'].median()

# %%
fig, ax = plt.subplots(figsize=(15,20), nrows=3, ncols=2)
fig.suptitle("Plotting Magnesium, OD280/OD315 of diluted Wines and Hue")

sns.boxplot(data=df, x='Magnesium', ax=ax[0,0], color='r')
ax[0,0].set_title('Box Plot for Magnesium')
sns.histplot(data=df, x="Magnesium", kde=True, ax=ax[0,1], color='r')
ax[0,1].axvline(mag_mean, color='black', linestyle='--', label="Mean")
ax[0,1].axvline(mag_median, color='grey', linestyle='-', label="Median")
ax[0,1].legend()
ax[0,1].set_title("Histogram for Magnesium")

sns.boxplot(data=df, x='OD280/OD315 of diluted Wines', ax=ax[1,0], color='g')
ax[1,0].set_title('Box Plot for OD280/OD315 of diluted Wines')
sns.histplot(data=df, x="OD280/OD315 of diluted Wines", kde=True, ax=ax[1,1], color='g')
ax[1,1].axvline(dil_mean, color='black', linestyle='--', label="Mean")
ax[1,1].axvline(dil_median, color='grey', linestyle='-', label="Median")
ax[1,1].legend()
ax[1,1].set_title("Histogram for OD280/OD315 of diluted Wines")

sns.boxplot(data=df, x='Hue', ax=ax[2,0])
ax[2,0].set_title('Box Plot for Hue')
sns.histplot(data=df, x="Hue", kde=True, ax=ax[2,1])
ax[2,1].axvline(hue_mean, color='black', linestyle='--', label="Mean")
ax[2,1].axvline(hue_median, color='grey', linestyle='-', label="Median")
ax[2,1].legend()
ax[2,1].set_title("Histogram for Hue")

plt.savefig('Subplot')

# %%
#This function measures the skewness
df.skew()
# Out:
# Class                           0.107431
# Alcohol                        -0.051482
# Malic acid                      1.039651
# Ash                            -0.176699
# Alcalinity of ash               0.213047
# Magnesium                       1.098191
# Total phenols                   0.086639
# Flavanoids                      0.025344
# Nonflavanoid phenols            0.450151
# Proanthocyanins                 0.517137
# Color intensity                 0.868585
# Hue                             0.021091
# OD280/OD315 of diluted Wines   -0.307285
# Proline                         0.767822
# dtype: float64

# %%
df['Magnesium'].skew()
# Out:
# 1.098191054755161

# %%
df_mag1 = np.sqrt(df['Magnesium'])
df_mag1.skew()
# Out:
# 0.8382312628407997

# %%
df_mag1
# Out:
# 0      11.269428
# 1      10.000000
# 2      10.049876
# 3      10.630146
# 4      10.862780
#          ...
# 173     9.746794
# 174    10.099505
# 175    10.954451
# 176    10.954451
# 177     9.797959
# Name: Magnesium, Length: 178, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,8), nrows=1, ncols=2)
fig.suptitle("Plotting Transformed Magnesium (Square Root)")

sns.boxplot(data=df_mag1, x=df_mag1, ax=ax[0])
ax[0].set_title('Box Plot for Magnesium')
sns.histplot(data=df_mag1, x=df_mag1, kde=True, ax=ax[1])
ax[1].set_title("Histogram for Magnesium")
# Out:
# Text(0.5, 1.0, 'Histogram for Magnesium')

# %%
df_mag2 = np.log(df['Magnesium'])
df_mag2.skew()
# Out:
# 0.6014446889284105

# %%
fig, ax = plt.subplots(figsize=(10,8), nrows=1, ncols=2)
fig.suptitle("Plotting Transformed Magnesium (Log)")

sns.boxplot(data=df_mag2, x=df_mag2, ax=ax[0])
ax[0].set_title('Box Plot for Magnesium')
sns.histplot(data=df_mag2, x=df_mag2, kde=True, ax=ax[1])
ax[1].set_title("Histogram for Magnesium")
# Out:
# Text(0.5, 1.0, 'Histogram for Magnesium')

# %%
df_mag3 = 1/df['Magnesium']
df_mag3.skew()
# Out:
# -0.17656461729558018

# %%
fig, ax = plt.subplots(figsize=(10,8), nrows=1, ncols=2)
fig.suptitle("Plotting Transformed Magnesium (1/x)")

sns.boxplot(data=df_mag3, x=df_mag3, ax=ax[0])
ax[0].set_title('Box Plot for Magnesium')
sns.histplot(data=df_mag3, x=df_mag3, kde=True, ax=ax[1])
ax[1].set_title("Histogram for Magnesium")
# Out:
# Text(0.5, 1.0, 'Histogram for Magnesium')

# %%
df_mag4 = pd.Series(sp.stats.boxcox(df['Magnesium'])[0])
df_mag4
# Out:
# 0      0.699041
# 1      0.698760
# 2      0.698774
# 3      0.698915
# 4      0.698964
#          ...
# 173    0.698686
# 174    0.698787
# 175    0.698982
# 176    0.698982
# 177    0.698702
# Length: 178, dtype: float64

# %%
lamb = sp.stats.boxcox(df['Magnesium'])[1]
lamb
# Out:
# -1.4291229687602396

# %%
fig, ax = plt.subplots(figsize=(10,8), nrows=1, ncols=2)
fig.suptitle("Plotting Transformed Magnesium (BoxCox)")

sns.boxplot(data=df_mag4, x=df_mag4, ax=ax[0])
ax[0].set_title('Box Plot for Magnesium')
sns.histplot(data=df_mag4, x=df_mag4, kde=True, ax=ax[1])
ax[1].set_title("Histogram for Magnesium")
# Out:
# Text(0.5, 1.0, 'Histogram for Magnesium')

# %%
fig, axes = plt.subplots(1,2,figsize=(16,4))
fig.suptitle("Original Data vs Transformed Data")
s1 = sp.stats.probplot(df['Magnesium'], plot=axes[0])
s2 = sp.stats.probplot(df_mag4, plot=axes[1])

# %%
filtered_df = df.drop(['Class', 'Magnesium'], axis=1)
filtered_df.rename(columns = {'OD280/OD315 of diluted Wines': 'OD280 or OD315 of diluted Wines'}, inplace=True)
filtered_df
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Total phenols  Flavanoids  \
# 0      14.23        1.71  2.43               15.6           2.80        3.06
# 1      13.20        1.78  2.14               11.2           2.65        2.76
# 2      13.16        2.36  2.67               18.6           2.80        3.24
# 3      14.37        1.95  2.50               16.8           3.85        3.49
# 4      13.24        2.59  2.87               21.0           2.80        2.69
# ..       ...         ...   ...                ...            ...         ...
# 173    13.71        5.65  2.45               20.5           1.68        0.61
# 174    13.40        3.91  2.48               23.0           1.80        0.75
# 175    13.27        4.28  2.26               20.0           1.59        0.69
# 176    13.17        2.59  2.37               20.0           1.65        0.68
# 177    14.13        4.10  2.74               24.5           2.05        0.76
#
# ...

# %%
filtered_df.columns
# Out:
# Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Total phenols',
#        'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins',
#        'Color intensity', 'Hue', 'OD280 or OD315 of diluted Wines', 'Proline'],
#       dtype='object')

# %%
def Plot(df, col):
    fig, ax = plt.subplots(1, 3, figsize=(25,10))
    skew = df[col].skew()
    fig.suptitle(f'Plots for {col}')
    sns.boxplot(data=df[col], x=df[col], ax=ax[0])
    ax[0].set_title('Box Plot')
    sns.histplot(data=df[col], x=df[col], kde=True, ax=ax[1], label=f'Skew: {skew}')
    ax[1].set_title('Histogram')
    ax[1].legend()
    sp.stats.probplot(df[col], plot=ax[2])
    ax[2].set_title('Probability Plot')
    plt.savefig(f'./Wine Dataset Plots/Original Plots/{col}')

# %%
for col in filtered_df:
    Plot(filtered_df, col)

# %% [markdown]
# ## Analysing the Skewness from the plots
# ### This analysis is through examining the Box plot, Histogram plot and the Skew Function values.
#
# * Malic Acid is Right Skewed.
# * Flavanoids is Right Skewed.
# * Nonflavanoid Phenol is Right Skewed.
# * Proanthocyanins is Right Skewed.
# * Color Intensity is Right Skewed.
# * Hue is a little bit Right Skewed.
# * OD280 or OD315 of diluted Wines is Left Skewed.
# * Proline is Right Skewed.

# %%
skewed_df = filtered_df.drop(['Alcohol', 'Ash', 'Alcalinity of ash', 'Total phenols'], axis=1)
skewed_df
# Out:
#      Malic acid  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0          1.71        3.06                  0.28             2.29
# 1          1.78        2.76                  0.26             1.28
# 2          2.36        3.24                  0.30             2.81
# 3          1.95        3.49                  0.24             2.18
# 4          2.59        2.69                  0.39             1.82
# ..          ...         ...                   ...              ...
# 173        5.65        0.61                  0.52             1.06
# 174        3.91        0.75                  0.43             1.41
# 175        4.28        0.69                  0.43             1.35
# 176        2.59        0.68                  0.53             1.46
# 177        4.10        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280 or OD315 of diluted Wines  Proline
# 0               5.64  1.04                             3.92     1065
# ...

# %%
skewed_df.skew()
# Out:
# Malic acid                         1.039651
# Flavanoids                         0.025344
# Nonflavanoid phenols               0.450151
# Proanthocyanins                    0.517137
# Color intensity                    0.868585
# Hue                                0.021091
# OD280 or OD315 of diluted Wines   -0.307285
# Proline                            0.767822
# dtype: float64

# %%
normalized_df = pd.DataFrame()

# %%
def Normalize(df):
    for col in df:
        series = pd.Series(sp.stats.boxcox(df[col])[0])
        normalized_df[col] = series

# %%
Normalize(skewed_df)
normalized_df
# Out:
#      Malic acid  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0      0.498435    1.734838             -1.078493         1.057792
# 1      0.532808    1.508768             -1.130654         0.264986
# 2      0.763944    1.867648             -1.028992         1.405015
# 3      0.609549    2.048911             -1.185841         0.980108
# 4      0.836270    1.455100             -0.832162         0.713148
# ..          ...         ...                   ...              ...
# 173    1.374665   -0.414462             -0.599815         0.059243
# 174    1.135061   -0.259303             -0.755304         0.379369
# 175    1.196201   -0.324767             -0.755304         0.327170
# 176    0.836270   -0.335822             -0.583789         0.422139
# 177    1.167339   -0.248530             -0.537001         0.327170
#
#      Color intensity       Hue  OD280 or OD315 of diluted Wines   Proline
# 0           1.848571  0.039910                         4.035440  4.968741
# ...

# %%
def Plot_Normalized(skewed_df, normalized_df, col):
    fig, ax = plt.subplots(1, 4, figsize=(25,10))
    original_skew = skewed_df[col].skew()
    normalized_skew = normalized_df[col].skew()
    fig.suptitle(f'Comparing Original vs Normalized Plots for {col}')
    sns.histplot(data=skewed_df[col], x=skewed_df[col], kde=True, ax=ax[0], label=f'Skew: {original_skew}', color= 'r')
    ax[0].set_title('Original Histogram')
    ax[0].legend()
    sns.histplot(data=normalized_df[col], x=normalized_df[col], kde=True, ax=ax[1], label=f'Skew: {normalized_skew}', color='y')
    ax[1].set_title('Normalized Histogram')
    ax[1].legend()
    sp.stats.probplot(skewed_df[col], plot=ax[2], )
    ax[2].set_title('Probability Plot for Original Data')
    sp.stats.probplot(normalized_df[col], plot=ax[3])
    ax[3].set_title('Probability Plot for Normalized Data')
    plt.savefig(f'./Wine Dataset Plots/Normalized Plots/{col}')

# %%
for col in skewed_df:
    Plot_Normalized(skewed_df, normalized_df, col)

# %% [markdown]
# All of these plots are saved in the folder 'Wine Dataset Plots'

# %% [markdown]
# # MDSC-102
# ## Assignment-IV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
names = ["Class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
df = pd.read_csv('./Resources/wine/wine.data', names=names)

# %%
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
sns.countplot(x="Alcohol", data=df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='count'>

# %%
sns.scatterplot(x="Alcohol", y="Malic acid", data=df, hue="Class", palette="bright")
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
plt.figure(figsize=(20,20))
for index, column in enumerate(df):
    if index > 1:
        plt.subplot(4,3,index-1)
        sns.scatterplot(x="Alcohol", y=column, data=df, hue="Class", palette="bright")

# %% [markdown]
# # Inference from the Scatter Plots
#
# ### Alcohol vs Malic acid
#
# * Class - 1 Wine: The Alcohol content is high while the Malic acid content is low comparatively
# * Class - 2 Wine: The Alcohol content is lower comparatively and the Malic acid content is similar to Class - 1's Malic acid content
# * Class - 3 Wine: The Alcohol content is moderate when compared with Class - 1 and 2 but the Malic acid content is the highest in this class.
#
# ### Alcohol vs Ash
#
# * Class - 1 Wine: The Alcohol content is high and the Ash content is high too.
# * Class - 2 Wine: The Alcohol content is low but the Ash content is high.
# * Class - 3 Wine: The Alcohol content is moderate and the Ash content is spread around the ranges but mostly is around the same levels as the Ash contents is Class 1 and 2.
#
# ### Alcohol vs Alcalinity of Ash
#
# * Class - 1 Wine: The Alcohol content is high but the Alcalinity of ash is low comparatively.
# * Class - 2 Wine: The Alcohol content is low but the Alcalinity of ash is high comparatively.
# * Class - 3 Wine: The Alcohol content is moderate and the Alacalinity of ash is mostly around the same levels as in Class 2.
#
# ### Alcohol vs Magnesium
#
# * Class - 1 Wine: The Alcohol content is high and the Magnesium content is moderate.
# * Class - 2 Wine: The Alcohol content is low but the Magnesium content seems high but those might be outlier values.
# * Class - 3 Wine: The Alcohol content is moderate and the Magnesium content is around the same levels as 2 except for the outliers.
#
# ### Alcohol vs Total phenols
#
# * Class - 1 Wine: The Alcohol content is high and the Total phenols levels are high too.
# * Class - 2 Wine: The Alcohol content is low but the Total phenols levels are spread around the ranges.
# * Class - 3 Wine: The Alcohol content is moderate and the Total phenols levels are the lowest compared to Class 1 and 2.
#
# ### Alcohol vs Flavanoids
#
# * Class - 1 Wine: The Alcohol content is high and the Flavanoids content is high too.
# * Class - 2 Wine: The Alcohol content is low but the Flavanoids content seems high due to one outlier point otherwise it is mostly around the same range as in Class 1.
# * Class - 3 Wine: The Alcohol content is moderate and the Flavanoids content is lowest compared to Class 1 and 2.
#
# ### Alcohol vs Nonfalavnoid phenols
#
# * Class - 1 Wine: The Alcohol content is high but the Nonflavanoid phenols levels are low.
# * Class - 2 Wine: The Alcohol content is low but the Nonflavanoid phenols levels are spread around and some points are high.
# * Class - 3 Wine: The Alcohol content is moderate and the Nonflavanoid phenols levels are spread around the ranges around the same levels as Class 2.
#
# ### Alcohol vs Proanthocyanins
#
# * Class - 1 Wine: The Alcohol content is high and the Proanthocyanins content is moderate.
# * Class - 2 Wine: The Alcohol content is low but the Proanhtocyanins content is high.
# * Class - 3 Wine: The Alcohol content is moderate but the Proanthocyanins content is low comparatively.
#
# ### Alcohol vs Color intensity
#
# * Class - 1 Wine: The Alcohol content is high and the Color intensity is moderate.
# * Class - 2 Wine: The Alcohol content is low and the Color intensity is low.
# * Class - 3 Wine: The Alcohol content is moderate and the Color intensity is high.
#
# ### Alcohol vs Hue
#
# * Class - 1 Wine: The Alcohol content is high and the Hue is moderate.
# * Class - 2 Wine: The Alcohol content is low but the Hue is moderate with few data points acting as outliers seemingly making it high.
# * Class - 3 Wine: The Alcohol content is moderate but the Hue is low comparatively.
#
# ### Alcohol vs OD280/OD315 of diluted wines
#
# * Class - 1 Wine: The Alcohol content is high and the OD280/OD315 of diluted wines is high too.
# * Class - 2 Wine: The Alcohol content is low but the OD280/OD315 of diluted wines is similar to Class 1.
# * Class - 3 Wine: The Alcohol content is moderate and the OD280/OD315 of diluted wines is the lowest of all the classes.
#
# ### Alcohol vs Proline
#
# * Class - 1 Wine: The Alcohol content is high and the Proline content is high too.
# * Class - 2 Wine: The Alcohol content is low but the Proline content is moderate.
# * Class - 3 Wine: The Alcohol content is moderate and the Proline content is around the same levels as Class 2.
